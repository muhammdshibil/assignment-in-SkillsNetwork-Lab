# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ##  __Muhammed Shibil__
#     Student

# %% [markdown]
# _I am interested in data science because it is a play ground for those who are having a craze with data and curious about the predictions by the data_

# %% [markdown]
# ### My code is very simple, it's going to add two numbers, if we give 2 values for a and b variables it's going to give the addition result as variable c

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %% [markdown]
# ## Numbered List
# 1. Number one
# 2. Number two
# 3. Number three
#
# ## Bulleted list
# * Bullet number one
# * Bullet number two
#
# ## Image
# ![QR CODE PIC1.jpg](attachment:52406664-2f92-4923-950a-92766a8a7024.jpg)
